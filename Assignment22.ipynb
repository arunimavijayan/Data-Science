# %% [markdown]
# 1. What is the result of the code, and explain?
#
# >>>X = 'iNeuron'
# >>> def func():
# print(X)
#
# >>> func()
#
# iNeuron .It displays the global value of X
#
# 2. What is the result of the code, and explain?
#
# >>> X = 'iNeuron'
# >>>def func():
# X ='NI!'
#
# >>>func()
# >>>print(X)
#
#
# iNeuron .It displays the global value of X since the changed value of X is only inside function scope.
#
# 3. What does this code print, and why?
#
# >>> X = 'iNeuron'
# >>> def func():
# X = 'NI'
# print(X)
#
# >>> func()
# >>> print(X)
#
# NI
# iNeuron. since x is printed inside also so it displays both and outside print prints global x value
#
# 4. What output does this code produce? Why?
#
# >>> X = 'iNeuron'
# >>> def func():
# global X
# X = 'NI'
#
# >>> func()
# >>>print(X)
#
# NI. value of global x is changed inside so prints the new X value
#
#
#
# 5. What about this code—what’s the output, and why?
#
# >>>X = 'iNeuron'
# >>> def func():
# X = 'NI';
# def nested():
# print(X)
# nested()
#
# >>> func()
# >>> X
#
# NI
# 'iNeuron' .value of x is same as the parent function and outside value of x is same as global
#
#
# 6. How about this code: what is its output in Python 3, and explain?
#
# >>> def func():
# X = 'NI'
# def nested():
# nonlocal X
# X = 'Spam'
# nested()
# print(X)
#
# >>> func()
#
#
# Spam. displays the changed value of X since local x value changed.

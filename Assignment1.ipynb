# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
#
# *-------------------------->expressions
# 'hello'-------------------->Values
# -87.8---------------------->Values
# -   ----------------------->expressions
# /   ----------------------->expressions
# +   ----------------------->expressions
# 6   ----------------------->values
#
#
#
# 2.What is the difference between string and variable?
#
# Variable is used to store values which can comprise of any datatype like str,int,bool,list,dict,set,tuple etc whereas String is one of the datatype which can be stored into a variable. String values are denoted using "" or '', anything enclosed within these quotes will be considered a string.
#
#
# 3. Describe three different data types.
#
# There are many data types in Python for eg:
#
#     Numeric Type: (int-->numbers without decimals, float--->numbers with decimals or e, complex---->numbers with real and imaginary part).These are mainly used to store numbers
#         eg: a=10 ----> a  is of int type
#             b=14.99 ---> b is of float type
#             c= 3+ 5j ----->c is of complex type
#
#     Sequence Type:(list--->sequence of mutable values ,tuple----->sequence of immutable value,range--->usually used in for loop to iterate and return a sequence of elements)
#         e.g: l=[1,2,3,4]---->l is a list
#              t=(1,2,3,4)-----> t is tuple
#              k=range(1,8)----> k will return series to numbers starting from 1 till 8 and by default it is incremented by 1
#
#      Mapping Type: dict----->has a key value pair and maps a particular value to a key.
#          eg: dict1={'a':'hi',b:9}---->dict1 is a dictionary
#
#
#  4. What is an expression made up of? What do all expressions do?
#
#  An expression consists of variables,operators or even method invocations, it follows a particular syntax according to the programming language used. All expressions evaluates to a result, result can be the product of arithmetic calulations, string manipulations or even return from any method etc.
#
#  5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
#  An expression consists of variables,operators or method invocations which evaluate to a result/value.
#  A statement consists of declaring a variable or displaying some content into the console
#  eg:
#  expression can be 1+9  ----->ths evaluates to a value
#  statement a=1+9 ------->this will strore the result of expression in a variable, this will not display anything unless it is printed
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Incase i run this in jupyter the value of bacon changes to 23.
# But if we run it somewhere else we need to print the value of bacon and incase we need to display the incremented value we will either have to write print(bacon+1) or store the updated value of bacon in it like bacon+=1 then print it.
#
# 7. What should the values of the following two terms be?
# 'spam'+'spamspam'------->'spamspamspam'
# 'spam'* 3  ------------->'spamspamspam'
#
# 8.Why is eggs a valid variable name while 100 is invalid?
#
#  Variable name connot begin with number. It should begin with letter,underscore
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
#  integer->int()
#  flosting-point number->float()
#  String->str()
#
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten' + 99 +'burritos';
#
# The above expression gives error because String cannot be concatenated with a int value so to fix this error we need to change the int to str. can be done in two ways put '' around 99 or enclose 99 inside str().
# 'I have eaten' + str(99) +'burritos';
#  or
#  a='I have eaten' + '99' +'burritos';
